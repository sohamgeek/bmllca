# %% [markdown]
# <a href="https://colab.research.google.com/github/sohamgeek/bmllca/blob/main/expt_1to_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing libraries

#there are a bunch of sun-libraries that will also be imported over here instead
#of being imported randomly throughout the cooding experience
import pandas as pd # type: ignore
import numpy as np # type: ignore
import seaborn as sns # type: ignore
from matplotlib import pyplot as plt # type: ignore
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import classification_report
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv("/content/IRIS (1).csv")

# %%
label_encoder=LabelEncoder()
#defining function
data['Species'] = label_encoder.fit_transform(data['Species'])
#encoding the label column for model training and fitting
data.head()
#checking if it worked
data=data.drop(columns=['ID'])
#droping the ID column as it is not usefull
data_plotting=data.drop(columns=['Species'])
#making a variable just to see the scatter plot without the species
sns.scatterplot(data=data_plotting)
#plotting the data once for better visualisation of our work
# Out:
# <Axes: >

# %%
#LOGISTIC REGRESSION
X=data[['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']].values
y=data[['Species']].values
#we over here will be predicting the species of flower using sepal and petal length.
#so we define the data into x and y
#train test split
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=0)

model=LogisticRegression()
#we put the value of logistic regression
model.fit(xtrain,ytrain)
#we will trainthe data
model.score(xtest,ytest)
# we see the accuracy score
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 1.0

# %%
#LINEAR REGRESSION
model=LinearRegression()
#we put the value of logistic regression
model.fit(xtrain,ytrain)
#we will trainthe data
model.score(xtest,ytest)
# we see the accuracy score
# Out:
# 0.9055032992676105

# %%
#NAIVE BAYES
model=GaussianNB()
model.fit(xtrain,ytrain)
model.score(xtest,ytest)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9666666666666667
